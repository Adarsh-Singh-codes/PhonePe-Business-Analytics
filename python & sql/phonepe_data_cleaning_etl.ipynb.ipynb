# %%
# -------------------------------------------------------
# 📦 STEP 0: SETUP & DATA UNDERSTANDING
# Project: PhonePe + UPI Payments Analytics
# Author: Adarsh Ajit Singh
# -------------------------------------------------------

import pandas as pd

pd.set_option('display.max_columns', None)

# -------------------------------------------------------
# 📂 Load the Datasets
# -------------------------------------------------------
phonepe_file = "/content/Phonepe-Final-Dataset.xlsx"
upi_file = "/content/UPI-Transactions-Enhanced.csv"

# Load only All_Transactions sheet for initial exploration
phonepe_df = pd.read_excel(phonepe_file, sheet_name="All_Transactions")

# Load UPI dataset
upi_df = pd.read_csv(upi_file)

# -------------------------------------------------------
# 🧭 Quick Exploration
# -------------------------------------------------------
print("✅ Datasets Loaded Successfully\n")

print("📘 PhonePe Shape:", phonepe_df.shape)
print("📘 UPI Shape:", upi_df.shape)

print("\n🔹 PhonePe Columns:")
print(phonepe_df.columns.tolist())

print("\n🔹 UPI Columns:")
print(upi_df.columns.tolist())

print("\n📊 PhonePe Sample:")
display(phonepe_df.head(3))

print("\n📊 UPI Sample:")
display(upi_df.head(3))

print("\n📈 Missing Values in UPI Dataset:")
print(upi_df.isnull().sum().head(10))
# Out:
# ✅ Datasets Loaded Successfully
#
# 📘 PhonePe Shape: (300000, 8)
# 📘 UPI Shape: (50000, 24)
#
# 🔹 PhonePe Columns:
# ['Transaction_ID', 'Amount', 'User_ID', 'Service', 'Service Type', 'Payment_Status', 'Reason', 'Date']
#
# 🔹 UPI Columns:
# ['Transaction_ID', 'Transaction_Date', 'Transaction_Time', 'Amount', 'Payment_Channel', 'Partner_Bank', 'Region', 'State', 'City_Tier', 'Device_Type', 'Service_Type', 'Payment_Status', 'Promo_Used', 'Referral_Source', 'Age_Group', 'Gender', 'Occupation', 'Failure_Reason', 'Platform_Fee_%', 'Revenue_Generated', 'PhonePe_Share_%', 'Transaction_Frequency', 'Engagement_Score', 'LTV_Score']
#
# 📊 PhonePe Sample:
#      Transaction_ID   Amount    User_ID         Service     Service Type  \
# 0  RCG_0C338474B366   926.59  PP0021371  Recharge_Bills  FASTag Recharge
# 1  RCG_6B3B86B07A76  1211.64  PP0002388  Recharge_Bills              DTH
# 2  RCG_767822392A0E   746.27  PP1101831  Recharge_Bills         Cable TV
#
#   Payment_Status      Reason       Date
# 0     Successful  Successful 2024-06-09
# 1     Successful  Successful 2024-08-04
# 2     Successful  Successful 2024-02-19
# 📊 UPI Sample:
#                          Transaction_ID Transaction_Date Transaction_Time  \
# 0  62aa4f34-7e48-4413-a2c3-91a6d28d31d7       2024-12-12         05:27:07
# 1  cac84924-d8be-425f-8f71-b9a6a756beae       2024-12-01         15:54:18
# 2  5e649248-51d5-4f4d-a3ba-bdfbd0265301       2024-12-09         18:43:16
#
#      Amount Payment_Channel   Partner_Bank Region        State City_Tier  \
# 0   4663.92          Intent     ICICI Bank   East        Assam    Tier-3
# 1   3084.65         QR Code            SBI   West  Maharashtra    Tier-1
# 2  30229.39         QR Code  IndusInd Bank  North        Delhi    Tier-2
#
#   Device_Type      Service_Type Payment_Status  Promo_Used Referral_Source  \
# 0     Android  Recharge & Bills        Success       False          Direct
# 1     Android  Recharge & Bills        Success        True          Direct
# 2     Android  Recharge & Bills        Success       False          Direct
#
#   Age_Group  Gender     Occupation Failure_Reason  Platform_Fee_%  \
# 0     25-34    Male  Self-Employed            NaN            0.30
# 1     25-34  Female       Salaried            NaN            0.87
# 2     35-44    Male        Student            NaN            0.45
#
#    Revenue_Generated  PhonePe_Share_%  Transaction_Frequency  \
# 0              13.99            35.33                     10
# 1              26.84            40.55                      1
# 2             136.03            41.59                      6
#
#    Engagement_Score  LTV_Score
# 0                62         59
# 1                72         47
# 2                98         63
# 📈 Missing Values in UPI Dataset:
# Transaction_ID      0
# Transaction_Date    0
# Transaction_Time    0
# Amount              0
# Payment_Channel     0
# Partner_Bank        0
# Region              0
# State               0
# City_Tier           0
# Device_Type         0
# dtype: int64

# %%
# -------------------------------------------------------
# 🧩 STEP 1: ETL CLEANING & STANDARDIZATION
# -------------------------------------------------------

import pandas as pd

# Reload datasets (if not already in memory)
phonepe_df = pd.read_excel("/content/Phonepe-Final-Dataset.xlsx", sheet_name="All_Transactions")
upi_df = pd.read_csv("/content/UPI-Transactions-Enhanced.csv")

# -------------------------------------------------------
# 🔹 1. Clean Column Names
# -------------------------------------------------------
phonepe_df.columns = (
    phonepe_df.columns.str.lower().str.strip().str.replace(" ", "_")
)
upi_df.columns = (
    upi_df.columns.str.lower().str.strip().str.replace(" ", "_")
)

# %%
# -------------------------------------------------------
# 🔹 2. Align UPI Columns to Match PhonePe
# -------------------------------------------------------
rename_map = {
    "transaction_id": "transaction_id",
    "transaction_date": "date",
    "transaction_amount": "transaction_amount",
    "service_type": "service_type",
    "payment_status": "payment_status",
    "failure_reason": "failure_reason",
    "region": "region",
    "state": "state"
}
upi_df.rename(columns=rename_map, inplace=True)

# %%
# -------------------------------------------------------
# 🔹 3. Clean Nulls & Formats
# -------------------------------------------------------
upi_df['date'] = pd.to_datetime(upi_df['date'], errors='coerce')
upi_df['failure_reason'] = upi_df['failure_reason'].fillna('None')
upi_df['payment_status'] = upi_df['payment_status'].str.capitalize()
upi_df.drop_duplicates(subset='transaction_id', inplace=True)

# %%
print("🔹 UPI Columns:")
print(list(upi_df.columns))
# Out:
# 🔹 UPI Columns:
# ['transaction_id', 'date', 'transaction_time', 'amount', 'payment_channel', 'partner_bank', 'region', 'state', 'city_tier', 'device_type', 'service_type', 'payment_status', 'promo_used', 'referral_source', 'age_group', 'gender', 'occupation', 'failure_reason', 'platform_fee_%', 'revenue_generated', 'phonepe_share_%', 'transaction_frequency', 'engagement_score', 'ltv_score', 'year', 'month', 'day_of_week', 'platform_fee_percent']

# %%
# -------------------------------------------------------
# 🔹 4. Add Derived Fields (Safe Check)
# -------------------------------------------------------

# Identify which column represents transaction amount
amount_col = None
for possible_col in ['transaction_amount', 'amount', 'txn_amount', 'value', 'upi_amount']:
    if possible_col in upi_df.columns:
        amount_col = possible_col
        break

if amount_col:
    upi_df['platform_fee_percent'] = 0.5
    upi_df['revenue_generated'] = upi_df[amount_col] * (upi_df['platform_fee_percent'] / 100)
else:
    print("⚠️ No transaction amount column found — please verify your dataset columns.")

# %%
# -------------------------------------------------------
# 🔹 5. Preview Cleaned Data
# -------------------------------------------------------
print("✅ Cleaned UPI Dataset:")
display(upi_df.head(10))

# -------------------------------------------------------
# 🔹 6. Save Locally for BigQuery Upload
# -------------------------------------------------------
upi_df.to_csv("/content/upi_cleaned.csv", index=False)
phonepe_df.to_csv("/content/phonepe_cleaned.csv", index=False)

print("\n✅ ETL complete! Cleaned datasets exported successfully.")
# Out:
# ✅ Cleaned UPI Dataset:
#                          transaction_id       date transaction_time    amount  \
# 0  62aa4f34-7e48-4413-a2c3-91a6d28d31d7 2024-12-12         05:27:07   4663.92
# 1  cac84924-d8be-425f-8f71-b9a6a756beae 2024-12-01         15:54:18   3084.65
# 2  5e649248-51d5-4f4d-a3ba-bdfbd0265301 2024-12-09         18:43:16  30229.39
# 3  ad55835c-4554-4e23-ac95-50eef74c6b75 2024-12-12         11:13:58  48307.51
# 4  ea40fc82-45cc-4512-bf0e-06a1b6b48824 2025-03-15         07:23:46  25160.93
# 5  5fccc408-52db-4012-bb70-a945700da5a0 2025-02-28         20:49:46   2623.19
# 6  56fcb124-acf2-4619-9c28-5439fde36e9f 2025-03-04         11:56:32  11099.87
# 7  47e4942d-f9ac-487f-aef4-a6e41740fe0b 2025-07-01         19:16:36  12277.41
# 8  7ceb5ec3-9e83-49be-92c6-a3239a6c1c21 2024-11-04         19:42:05  16925.96
# 9  b2431183-5155-443b-ab35-b5d6b3c6a22b 2025-03-31         01:43:01   2227.99
#
#   payment_channel    partner_bank region           state city_tier  \
# 0          Intent      ICICI Bank   East           Assam    Tier-3
# 1         QR Code             SBI   West     Maharashtra    Tier-1
# 2         QR Code   IndusInd Bank  North           Delhi    Tier-2
# 3   Bank Transfer   IndusInd Bank   East           Assam    Tier-3
# 4         QR Code      Union Bank   East     West Bengal    Tier-2
# 5         QR Code       Axis Bank   West     Maharashtra    Tier-3
# 6          Intent  Bank of Baroda  North           Delhi    Tier-1
# 7          UPI ID   IndusInd Bank  North         Haryana    Tier-2
# 8          UPI ID      ICICI Bank   East           Bihar    Tier-2
# 9         QR Code       Axis Bank  South  Andhra Pradesh    Tier-3
#
#   device_type      service_type payment_status  promo_used  \
# 0     Android  Recharge & Bills        Success       False
# 1     Android  Recharge & Bills        Success        True
# 2     Android  Recharge & Bills        Success       False
# 3     Android             Loans        Success        True
# 4     Android         Insurance        Success       False
# 5     Android         Insurance        Success       False
# 6     Android    Money Transfer        Success       False
# 7         iOS  Recharge & Bills           Fail       False
# 8     Android             Loans        Success       False
# 9     Android    Money Transfer        Success       False
#
#       referral_source age_group  gender     occupation failure_reason  \
# 0              Direct     25-34    Male  Self-Employed           None
# 1              Direct     25-34  Female       Salaried           None
# 2              Direct     35-44    Male        Student           None
# 3  Marketing Campaign     45-54  Female        Student           None
# 4              Direct     25-34  Female       Salaried           None
# 5              Direct     35-44    Male       Salaried           None
# 6              Direct     45-54    Male        Retired           None
# 7            Referral     35-44  Female        Student   Bank Timeout
# 8              Direct     35-44  Female        Student           None
# 9              Direct     18-24    Male        Student           None
#
#    platform_fee_%  revenue_generated  phonepe_share_%  transaction_frequency  \
# 0            0.30           23.31960            35.33                     10
# 1            0.87           15.42325            40.55                      1
# 2            0.45          151.14695            41.59                      6
# 3            0.51          241.53755            40.94                     12
# 4            0.56          125.80465            40.22                      6
# 5            0.43           13.11595            35.63                     19
# 6            0.22           55.49935            35.05                     20
# 7            0.61           61.38705            41.50                     12
# 8            0.70           84.62980            42.96                     24
# 9            0.30           11.13995            44.34                     20
#
#    engagement_score  ltv_score  year  month day_of_week  platform_fee_percent
# 0                62         59  2024     12    Thursday                   0.5
# 1                72         47  2024     12      Sunday                   0.5
# 2                98         63  2024     12      Monday                   0.5
# 3                90         87  2024     12    Thursday                   0.5
# 4                92         77  2025      3    Saturday                   0.5
# 5                99         86  2025      2      Friday                   0.5
# 6                62         43  2025      3     Tuesday                   0.5
# 7                53         60  2025      7     Tuesday                   0.5
# 8                92         42  2024     11      Monday                   0.5
# 9                90         63  2025      3      Monday                   0.5
# ✅ ETL complete! Cleaned datasets exported successfully.
